# %% [markdown]
# <a href="https://colab.research.google.com/github/Alissa-Ouspen/data201_alissa/blob/main/week1/Class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 1
y = 2

# %%
z = x + y

# %%
w = x**2
print(w)
# Out:
# 1

# %%
#Example 2.14
import matplotlib.pyplot as plt
import numpy as np

x = [i for i in range(100)]
x = np.array(x)
x = 2 * np.pi* x * 0.01
y = np.sin(x)
plt.plot(x,y)
plt.title('Sin Plot')
plt.xlabel('x')
plt.ylabel('Sin')
plt.show()

# %%
x = [1, 2, 3]
w = np.mean(x)
print(w)
# Out:
# 2.0

# %%
x_int = 3
x_float = 3.0
x_bool = True
x_none = None

# %%
type(x_float)
# Out:
# float

# %%
myList = [1, 2, 3, 4]

# %%
myList[0]
#myList[3]
# Out:
# 1

# %%
myList[1:3]

# myList[a:b]  returns from a up to but excluding b
# Out:
# [2, 3]

# %%
np.nan + 1

# "missing number"
# "None" is for non-numeric values

#  np.nan in numeric arrays
#  pd.isna() in pandas
# Out:
# nan

# %%
myTuple = (1, 2, 3)

# immutable list

# %%
myDictionary = {"a": 10, "b": 20, "c": 30}
myDictionary["b"]
# Out:
# 20

# %%
x = 5
if x > 0:
  print("positive")
elif x < 0:
  print("negative")
else:
  print("zero")
# Out:
# positive

# %%
x = 5
result = "pos" if x > 0 else "neg or zero"
print(result)
# Out:
# pos

# %%
x = 5
result = ("neg or zero", "pos") [x > 0]
print(result)

# false condition goes first!
# Out:
# pos
