# %% [markdown]
# <a href="https://colab.research.google.com/github/Alissa-Ouspen/data201_alissa/blob/main/week2/Wk_2_Assign_Alissa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Assignment 2 – Data Wrangling with pandas
#
# #### Index, assign, groupby, aggregate, sort, logic, chaining

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", 20)

# %%
dt = pd.read_csv(
    "https://raw.githubusercontent.com/Alissa-Ouspen/data201_alissa/refs/heads/main/datasets/housing.csv")
pd.options.display.float_format = '{:.2f}'.format
dt.head(10)
# Out:
#    listing_id    price    size  bedrooms neighborhood          type
# 0      100001  1500000 1280.74      1.00       Suburb     Townhouse
# 1      100002  1500000 1406.28      2.00       Uptown  SingleFamily
# 2      100003  1500000 4146.83      6.00       Suburb   MultiFamily
# 3      100004  1500000 3946.60      6.00       Suburb  SingleFamily
# 4      100005  1500000 1243.75      1.00     Downtown   MultiFamily
# 5      100006  1500000     NaN      4.00   Waterfront  SingleFamily
# 6      100007  1500000 1404.98      1.00       Suburb  SingleFamily
# 7      100008  1500000  838.95      1.00       Suburb         Condo
# 8      100009  1500000 1650.93      1.00     Downtown  SingleFamily
# 9      100010  1500000 1153.73       NaN       Uptown     Townhouse

# %%
#dt.dropna(subset = ["size"])   # not needed
# Out:
#      listing_id    price    size  bedrooms neighborhood          type
# 0        100001  1500000 1280.74      1.00       Suburb     Townhouse
# 1        100002  1500000 1406.28      2.00       Uptown  SingleFamily
# 2        100003  1500000 4146.83      6.00       Suburb   MultiFamily
# 3        100004  1500000 3946.60      6.00       Suburb  SingleFamily
# 4        100005  1500000 1243.75      1.00     Downtown   MultiFamily
# ..          ...      ...     ...       ...          ...           ...
# 595      100596  1500000 1443.24      3.00      Midtown         Condo
# 596      100597  1500000 1083.91      2.00       Suburb         Condo
# 597      100598  1500000 1600.13      1.00       Suburb  SingleFamily
# 598      100599  1500000 1248.22      1.00   Waterfront         Condo
# 599      100600  1500000 1450.98       NaN       Suburb  SingleFamily
#
# [547 rows x 6 columns]

# %%
ds = (dt[(dt["price"] > 250000) & (dt["size"] > 1000)]
      .assign(ppsqft = dt["price"] / dt["size"])
      .groupby("neighborhood")    # must be grouped first
      .agg(
        mean_ppsqft = ("ppsqft", "mean"),
        median_ppsqft = ("ppsqft", "median"),
        count = ("ppsqft", "count")
      )
      .sort_values(by = ["neighborhood"], ascending = True)
)
ds
# Out:
#               mean_ppsqft  median_ppsqft  count
# neighborhood
# Downtown           977.82        1001.56     99
# Midtown            921.14         901.99     92
# Suburb             861.92         836.88    157
# Uptown             860.94         843.65     99
# Waterfront         849.51         792.66     48

# %% [markdown]
# ## Reflection
#
# I like the way R does not require quotes and parentheses or brackets for commands.  At least, a lot less parentheses.  Python is really painful about this.
#
# I like the pipe/ chaining method with R better.
# The logic flow looks cleaner and is easer to read.
#
# However, the formatting command is more complicated in R.
#
# Besides the wording, things are pretty similar.
# The output in ipynb looks the same, although I haven't tested it in other formats.

# %% [markdown]
# ## Part C:  Boolean logic

# %%
dt[
    (dt["price"] > 250000) & (dt["size"] > 1000)].head()
# Out:
#    listing_id    price    size  bedrooms neighborhood          type
# 0      100001  1500000 1280.74      1.00       Suburb     Townhouse
# 1      100002  1500000 1406.28      2.00       Uptown  SingleFamily
# 2      100003  1500000 4146.83      6.00       Suburb   MultiFamily
# 3      100004  1500000 3946.60      6.00       Suburb  SingleFamily
# 4      100005  1500000 1243.75      1.00     Downtown   MultiFamily

# %%
#  this produces an error
#  dt[dt["price"] > 250000 & dt["size"] > 1000].head()

# %% [markdown]
# Python looks at all the logical operators in order of precedence,
# so parentheses must be used to separate items that need to be
# compared or evaluated.
# In the incorrect code,
#  Python compares
# dt[dt["price"]  to
# 250000 & dt["size"].

# %%
dt.query("price > 250000 and size > 1000").head()
# Out:
#    listing_id    price    size  bedrooms neighborhood          type
# 0      100001  1500000 1280.74      1.00       Suburb     Townhouse
# 1      100002  1500000 1406.28      2.00       Uptown  SingleFamily
# 2      100003  1500000 4146.83      6.00       Suburb   MultiFamily
# 3      100004  1500000 3946.60      6.00       Suburb  SingleFamily
# 4      100005  1500000 1243.75      1.00     Downtown   MultiFamily

# %% [markdown]
# ## Part D
#
# 1. We wrap conditions in parentheses, because "&" is a logical operator and can get confused with other logical operators.
#
# 2.  Creating multiple temporary DataFrames is time-intensive for the programmer and resource-intensive for the server.
#
# 3.  In `.agg(mean_price=("price", "mean"))`, '" price"' is the object upon which the action of finding the mean is executed.
#
# 4.  In `groupby("neighborhood")`, `neighborhood` appears as the index on the left, because it is the group key by which the data is organized (aggregated).

# %%
(dt
      .groupby("type")
      .agg(
        mean_price = ("price", "mean"),
        median_price = ("price", "median"),
        count = ("price", "count")
      )
)
# Out:
#               mean_price  median_price  count
# type
# Condo         1500000.00    1500000.00    183
# MultiFamily   1500000.00    1500000.00     63
# SingleFamily  1500000.00    1500000.00    235
# Townhouse     1500000.00    1500000.00    119

# %% [markdown]
# The above is correct, because every single price is the same:  1500000.
